# %%
clone GitHub repo

# %%
#!git config --global user.name "lupor01"
#!git config --global user.email "191704986+lupor01@users.noreply.github.com"

# !git clone https://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@github.com/Birkbeck/msc-project-source-code-files-24-25-lupor01.git

# %cd Birkbeck/msc-project-source-code-files-24-25-lupor01.git
# Out:
# Cloning into 'msc-project-source-code-files-24-25-lupor01'...
# remote: Enumerating objects: 1497, done.
# remote: Counting objects: 100% (339/339), done.
# remote: Compressing objects: 100% (208/208), done.
# remote: Total 1497 (delta 195), reused 262 (delta 121), pack-reused 1158 (from 1)
# Receiving objects: 100% (1497/1497), 90.34 MiB | 40.97 MiB/s, done.
# Resolving deltas: 100% (994/994), done.
# [Errno 2] No such file or directory: 'Birkbeck/msc-project-source-code-files-24-25-lupor01.git'
# /content

# %% [markdown]
# Install pathlib for file management (unavailable in Colab Environment)

# %%
# !pip install pathlib
# Out:
# Collecting pathlib
#   Downloading pathlib-1.0.1-py3-none-any.whl.metadata (5.1 kB)
# Downloading pathlib-1.0.1-py3-none-any.whl (14 kB)
# Installing collected packages: pathlib
# Successfully installed pathlib-1.0.1

# %% [markdown]
# set working directory

# %%
import os

print(os.getcwd())
#print(os.chdir(".."))
os.chdir("./msc-project-source-code-files-24-25-lupor01")
#os.chdir("./nsga")
#print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['nsga-playground.py', '.git', 'ga-playground.ipynb', '.gitignore', 'LICENSE', 'README.md', 'whole', 'ga-playground.py', 'analysis.ipynb', 'analysis.py', '.DS_Store']

# %% [markdown]
# set experimental parameters

# %%
import torch
from whole.nsga.models import TinyConvClassifier, TinyFlexyConvAE

# –––––----- experiment details ––––––––––– #
dataset = "mnist" # mnist, cifar, fashion
problem = "classification"
prestep = False
condition = "AE" if prestep else "noAE"
subset_fraction = 0.2 # 0.07

model1 = TinyConvClassifier # main model
model2 = TinyFlexyConvAE # autoencoder for AE condition

interval = [1, 5]

pop = 60 #60
bound_runs = 5 #5
bound_gens = 5 #5
evo_runs = 6 #31
evo_gens = 50 #50
AEepochs = 4
interspecies_r = 0.01 # was 6% # increase to ~20-30%?????

seed = 34
mutation_rate_min = 0.01
mutation_rate_max = 0.3
mutation_rate_decay = True
mutation_strength = 0.2
mutation_mode = "light"

resume = True # from checkpoint?
mydevice = torch.device("cuda" if torch.cuda.is_available() else "cpu")
git = False
checkpoint = True

# %% [markdown]
# set filepath for saves/checkpointing

# %%
from pathlib import Path

print(os.getcwd())
# move to appropriate nsga directory
name = "nsga"
basedir = None
cwd = Path().cwd().resolve()
if cwd.name != name:
    try:
        basedir = next(e for e in cwd.rglob("*") if e.is_dir() and e.name == name)
    except StopIteration:
        raise FileNotFoundError("could not find nsga directory")
else:
    basedir = cwd

print(os.getcwd())
basepath = basedir / "whole" / "tests" / "NSGA" / f"{dataset}" / f"{condition}"

basepath.mkdir(parents=True, exist_ok=True)
# Out:
# /content/msc-project-source-code-files-24-25-lupor01
# /content/msc-project-source-code-files-24-25-lupor01

# %% [markdown]
# # Initialise and run NSGA experiment

# %%
import os
import whole.nsga.experiment as exp


# --–––---––– initialisation –––---–––-- #
print("\nstarting workflow!")
workflow = exp.ExperimentV4(
    model1=model1,
    model2=model2,
    pop=pop,
    dataset=dataset,
    subset_fraction=subset_fraction,
    problem=problem,
    bound_runs=bound_runs,
    bound_gens=bound_gens,
    evo_runs=evo_runs,
    evo_gens=evo_gens,
    prestep=prestep, # autoencoder condition?
    intersp_cross_rate=interspecies_r,
    mutation_rate_min=mutation_rate_min,
    mutation_rate_max=mutation_rate_max,
    mutation_rate_decay=mutation_rate_decay,
    mutation_strength=mutation_strength,
    mutation_mode=mutation_mode,
    interval=interval,
    seed=seed,
    experiment_path=basepath,
    resume=resume, # from checkpoint?
    device=mydevice,
    git=git,
    checkpoint=checkpoint
)


# --––––- experiment --–––- #
workflow.run()


print("\nexperiment's over.. g'byeeee")

# results = workflow.get_results()
# Out:
# starting workflow!
#
# resuming experiment: 5 runs gone..
#
# * starting experimental runs..
#
# * initiating round 5
#   - model evolution..
# gen:0|cross-species: 0|#topo:5|avg_val: 0.117|avg_conv: 1.147| ∆: nan
# gen:1|cross-species: 1|#topo:5|avg_val: 0.127|avg_conv: 1.104| ∆: nan
# gen:2|cross-species: 1|#topo:5|avg_val: 0.133|avg_conv: 1.075| ∆: nan
# gen:3|cross-species: 1|#topo:5|avg_val: 0.136|avg_conv: 1.062| ∆: nan
# gen:4|cross-species: 0|#topo:5|avg_val: 0.141|avg_conv: 1.05| ∆: nan
# gen:5|cross-species: 1|#topo:5|avg_val: 0.143|avg_conv: 1.04| ∆: nan
# gen:6|cross-species: 1|#topo:5|avg_val: 0.147|avg_conv: 1.028| ∆: nan
# gen:7|cross-species: 0|#topo:5|avg_val: 0.149|avg_conv: 1.023| ∆: nan
# gen:8|cross-species: 0|#topo:5|avg_val: 0.153|avg_conv: 1.015| ∆: nan
# gen:9|cross-species: 0|#topo:5|avg_val: 0.155|avg_conv: 1.009| ∆: nan
# gen:10|cross-species: 0|#topo:5|avg_val: 0.157|avg_conv: 1.008| ∆: nan
# gen:11|cross-species: 1|#topo:5|avg_val: 0.16|avg_conv: 1.004| ∆: nan
# gen:12|cross-species: 0|#topo:5|avg_val: 0.161|avg_conv: 1.003| ∆: nan
# gen:13|cross-species: 0|#topo:5|avg_val: 0.163|avg_conv: 1.002| ∆: nan
# gen:14|cross-species: 0|#topo:5|avg_val: 0.164|avg_conv: 1.001| ∆: nan
# gen:15|cross-species: 0|#topo:5|avg_val: 0.164|avg_conv: 1.0| ∆: nan
# gen:16|cross-species: 1|#topo:5|avg_val: 0.165|avg_conv: 1.0| ∆: nan
# gen:17|cross-species: 1|#topo:5|avg_val: 0.165|avg_conv: 1.0| ∆: nan
# gen:18|cross-species: 2|#topo:5|avg_val: 0.165|avg_conv: 1.0| ∆: nan
# gen:19|cross-species: 0|#topo:5|avg_val: 0.165|avg_conv: 1.0| ∆: nan
# gen:20|cross-species: 0|#topo:5|avg_val: 0.165|avg_conv: 1.0| ∆: nan
# gen:21|cross-species: 0|#topo:5|avg_val: 0.165|avg_conv: 1.0| ∆: nan
# gen:22|cross-species: 1|#topo:5|avg_val: 0.166|avg_conv: 1.0| ∆: nan
# gen:23|cross-species: 0|#topo:5|avg_val: 0.166|avg_conv: 1.0| ∆: nan
# gen:24|cross-species: 0|#topo:5|avg_val: 0.166|avg_conv: 1.0| ∆: nan
# gen:25|cross-species: 1|#topo:5|avg_val: 0.165|avg_conv: 1.0| ∆: nan
# gen:26|cross-species: 2|#topo:5|avg_val: 0.166|avg_conv: 1.0| ∆: nan
# gen:27|cross-species: 0|#topo:5|avg_val: 0.166|avg_conv: 1.0| ∆: nan
# gen:28|cross-species: 2|#topo:5|avg_val: 0.166|avg_conv: 1.0| ∆: nan
# gen:29|cross-species: 0|#topo:5|avg_val: 0.166|avg_conv: 1.0| ∆: nan
# gen:30|cross-species: 0|#topo:5|avg_val: 0.166|avg_conv: 1.0| ∆: nan
# gen:31|cross-species: 0|#topo:5|avg_val: 0.166|avg_conv: 1.0| ∆: nan
# gen:32|cross-species: 0|#topo:5|avg_val: 0.166|avg_conv: 1.0| ∆: nan
# gen:33|cross-species: 1|#topo:5|avg_val: 0.166|avg_conv: 1.0| ∆: nan
# gen:34|cross-species: 0|#topo:5|avg_val: 0.166|avg_conv: 1.0| ∆: nan
# gen:35|cross-species: 0|#topo:5|avg_val: 0.165|avg_conv: 1.0| ∆: nan
# gen:36|cross-species: 0|#topo:5|avg_val: 0.166|avg_conv: 1.0| ∆: nan
# gen:37|cross-species: 1|#topo:5|avg_val: 0.166|avg_conv: 1.0| ∆: nan
# gen:38|cross-species: 0|#topo:5|avg_val: 0.166|avg_conv: 1.0| ∆: nan
# gen:39|cross-species: 1|#topo:5|avg_val: 0.166|avg_conv: 1.0| ∆: nan
# gen:40|cross-species: 0|#topo:5|avg_val: 0.166|avg_conv: 1.0| ∆: nan
# gen:41|cross-species: 0|#topo:5|avg_val: 0.166|avg_conv: 1.0| ∆: nan
# gen:42|cross-species: 0|#topo:5|avg_val: 0.165|avg_conv: 1.0| ∆: nan
# gen:43|cross-species: 0|#topo:5|avg_val: 0.166|avg_conv: 1.0| ∆: nan
# gen:44|cross-species: 0|#topo:5|avg_val: 0.165|avg_conv: 1.0| ∆: nan
# gen:45|cross-species: 0|#topo:5|avg_val: 0.165|avg_conv: 1.0| ∆: nan
# gen:46|cross-species: 0|#topo:5|avg_val: 0.166|avg_conv: 1.0| ∆: nan
# gen:47|cross-species: 0|#topo:5|avg_val: 0.166|avg_conv: 1.0| ∆: nan
# gen:48|cross-species: 1|#topo:5|avg_val: 0.166|avg_conv: 1.0| ∆: nan
# gen:49|cross-species: 0|#topo:5|avg_val: 0.166|avg_conv: 1.0| ∆: nan
#   - evolution finished.. 5 run finished..
# avg test accuracy: 0.16549400793650795
#
#   - hit checkpoint! next run coming..
#
# * initiating round 6
#   - model evolution..
# gen:0|cross-species: 0|#topo:5|avg_val: 0.117|avg_conv: 1.155| ∆: nan
