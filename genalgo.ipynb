# %%
#!git config --global user.name "lupor01"
#!git config --global user.email "191704986+lupor01@users.noreply.github.com"

# !git clone https://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@github.com/Birkbeck/msc-project-source-code-files-24-25-lupor01.git

# %cd Birkbeck/msc-project-source-code-files-24-25-lupor01.git
# Out:
# Cloning into 'msc-project-source-code-files-24-25-lupor01'...
# remote: Enumerating objects: 1416, done.
# remote: Counting objects: 100% (258/258), done.
# remote: Compressing objects: 100% (152/152), done.
# remote: Total 1416 (delta 154), reused 198 (delta 97), pack-reused 1158 (from 1)
# Receiving objects: 100% (1416/1416), 88.46 MiB | 14.08 MiB/s, done.
# Resolving deltas: 100% (953/953), done.
# [Errno 2] No such file or directory: 'Birkbeck/msc-project-source-code-files-24-25-lupor01.git'
# /content

# %%
# !pip install pathlib
# Out:
# Collecting pathlib
#   Downloading pathlib-1.0.1-py3-none-any.whl.metadata (5.1 kB)
# Downloading pathlib-1.0.1-py3-none-any.whl (14 kB)
# Installing collected packages: pathlib
# Successfully installed pathlib-1.0.1

# %%
import os

print(os.getcwd())
#print(os.chdir(".."))
os.chdir("./msc-project-source-code-files-24-25-lupor01")
#os.chdir("./nsga")
#print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['nsga-playground.py', '.git', 'README.md', 'ga-playground.py', '.gitignore', '.DS_Store', 'LICENSE', 'ga-playground.ipynb', 'whole']

# %%
from pathlib import Path
import os
import torch
from torch.utils.data import DataLoader
from torchvision.datasets import MNIST
from torchvision.transforms import ToTensor
from whole.ga.models import TinyFlexyConvAE, TinyConvClassifier, create_AE_pop
import whole.ga.genalgo as gen

# %%
dataset = "mnist" # mnist / kmnist / fashion   #⛔️ mnist, fashion done | kmnist misses noAE
subset_fraction = 0.2 # initially, 0.07
problem = "classification"
classes = 10

autoencoder = TinyFlexyConvAE
classifier = TinyConvClassifier
pop = 50
runs = 10 # baseline, 30 ?
gens = 50 # baseline, 30 ?
stride = 2
AEepochs = 4

seed = 34
mutation_rate_min = 0.01
mutation_rate_max = 0.3
mutations_rate_decay = True
mutation_strength = 0.2
mutation_mode = "light"

my_device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
resume = False
checkpoint = True

# %%
presteps = [False]

for prestep in presteps:
  condition = "AE" if prestep else "noAE"

  # --------- file management -------- #
  print(os.getcwd())
  # move to appropriate nsga directory

  name = "msc-project-source-code-files-24-25-lupor01"
  basedir = None
  cwd = Path().cwd().resolve()
  if cwd.name != name:
    try:
      basedir = next(e for e in cwd.rglob("*") if e.is_dir() and e.name == name)
    except StopIteration:
      raise FileNotFoundError("could not find directory")
  else:
    basedir = cwd
  basepath = basedir / "whole" / "tests" / "GA" / f"{dataset}" / f"{condition}"
  basepath.mkdir(parents=True, exist_ok=True)


  # ---------- experiment ----------- #
  workflow = gen.GAExperiment(
      model1=classifier, # task model
      model2=autoencoder, # autoencoder
      stride=stride,
      pop=pop,
      dataset=dataset,
      subset_fraction=subset_fraction,
      problem=problem,
      seed=seed,
      experiment_path=basepath,
      prestep=prestep,
      AEepochs=AEepochs,
      classes=classes,
      runs=runs,
      gens=gens,
      mutation_rate_min=mutation_rate_min,
      mutation_rate_max=mutation_rate_max,
      mutation_rate_decay=mutations_rate_decay,
      mutation_strength=mutation_strength,
      mutation_mode=mutation_mode,
      my_device=my_device,
      resume=resume,
      checkpoint=checkpoint
  )

  print(f"\ndataset: {dataset}\n")

  workflow.run()

  print("\nexperiment's over!")
# Out:
# /content/msc-project-source-code-files-24-25-lupor01
#
# dataset: mnist
# 100%|██████████| 9.91M/9.91M [00:02<00:00, 4.95MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 134kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.24MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 8.89MB/s]
# * starting experiment. AE condition: False
#   - run 0
# 0 gen | avg. population acc: 0.11916998773813248
# 1 gen | avg. population acc: 0.12321832776069641
# 2 gen | avg. population acc: 0.1305466741323471
# 3 gen | avg. population acc: 0.136188343167305
# 4 gen | avg. population acc: 0.14529332518577576
# 5 gen | avg. population acc: 0.15386833250522614
# 6 gen | avg. population acc: 0.16155000030994415
# 7 gen | avg. population acc: 0.16791000962257385
# 8 gen | avg. population acc: 0.17357000708580017
# 9 gen | avg. population acc: 0.18119500577449799
# 10 gen | avg. population acc: 0.18635836243629456
# 11 gen | avg. population acc: 0.1890299916267395
# 12 gen | avg. population acc: 0.19519832730293274
# 13 gen | avg. population acc: 0.1963450014591217
# 14 gen | avg. population acc: 0.2003183364868164
# 15 gen | avg. population acc: 0.20213499665260315
# 16 gen | avg. population acc: 0.20495334267616272
# 17 gen | avg. population acc: 0.20735666155815125
# 18 gen | avg. population acc: 0.21122333407402039
# 19 gen | avg. population acc: 0.21266499161720276
# 20 gen | avg. population acc: 0.21549667418003082
# 21 gen | avg. population acc: 0.2188483476638794
# 22 gen | avg. population acc: 0.22304999828338623
# 23 gen | avg. population acc: 0.22553998231887817
# 24 gen | avg. population acc: 0.2277066856622696
# 25 gen | avg. population acc: 0.23185667395591736
# 26 gen | avg. population acc: 0.23578666150569916
# 27 gen | avg. population acc: 0.23890499770641327
# 28 gen | avg. population acc: 0.24320334196090698
# 29 gen | avg. population acc: 0.2500166594982147
# 30 gen | avg. population acc: 0.2541566491127014
# 31 gen | avg. population acc: 0.2586166560649872
# 32 gen | avg. population acc: 0.26201000809669495
# 33 gen | avg. population acc: 0.2649500072002411
# 34 gen | avg. population acc: 0.2660333216190338
# 35 gen | avg. population acc: 0.26748499274253845
# 36 gen | avg. population acc: 0.26939332485198975
# 37 gen | avg. population acc: 0.2726899981498718
# 38 gen | avg. population acc: 0.2748066782951355
# 39 gen | avg. population acc: 0.27598997950553894
# 40 gen | avg. population acc: 0.27857834100723267
# 41 gen | avg. population acc: 0.2824766933917999
# 42 gen | avg. population acc: 0.2836116850376129
# 43 gen | avg. population acc: 0.2865050137042999
# 44 gen | avg. population acc: 0.28940334916114807
# 45 gen | avg. population acc: 0.29256170988082886
# 46 gen | avg. population acc: 0.2957399785518646
# 47 gen | avg. population acc: 0.3001466691493988
# 48 gen | avg. population acc: 0.303629994392395
# 49 gen | avg. population acc: 0.3070499897003174
# avg test accuracy: 0.3099
#
#   - hit checkpoint! next run coming..
#   - run 1
# 0 gen | avg. population acc: 0.10282833129167557
# 1 gen | avg. population acc: 0.12465333938598633
# 2 gen | avg. population acc: 0.13569334149360657
# 3 gen | avg. population acc: 0.14347165822982788
# 4 gen | avg. population acc: 0.15267999470233917
# 5 gen | avg. population acc: 0.15924833714962006
# 6 gen | avg. population acc: 0.16358666121959686
# 7 gen | avg. population acc: 0.1658400148153305
# 8 gen | avg. population acc: 0.17156332731246948
# 9 gen | avg. population acc: 0.17429500818252563
# 10 gen | avg. population acc: 0.17963667213916779
# 11 gen | avg. population acc: 0.18583166599273682
# 12 gen | avg. population acc: 0.19153833389282227
# 13 gen | avg. population acc: 0.19768498837947845
# 14 gen | avg. population acc: 0.20213335752487183
# 15 gen | avg. population acc: 0.2056383341550827
# 16 gen | avg. population acc: 0.21139000356197357
# 17 gen | avg. population acc: 0.2163933366537094
# 18 gen | avg. population acc: 0.22300665080547333
# 19 gen | avg. population acc: 0.23050667345523834
# 20 gen | avg. population acc: 0.23535668849945068
# 21 gen | avg. population acc: 0.23868998885154724
# 22 gen | avg. population acc: 0.2437949925661087
# 23 gen | avg. population acc: 0.2511233389377594
# 24 gen | avg. population acc: 0.2604050040245056
# 25 gen | avg. population acc: 0.2671132981777191
# 26 gen | avg. population acc: 0.27447664737701416
# 27 gen | avg. population acc: 0.27836668491363525
# 28 gen | avg. population acc: 0.28054168820381165
# 29 gen | avg. population acc: 0.2839333415031433
# 30 gen | avg. population acc: 0.28521668910980225
# 31 gen | avg. population acc: 0.28825169801712036
# 32 gen | avg. population acc: 0.29116499423980713
# 33 gen | avg. population acc: 0.2935049831867218
# 34 gen | avg. population acc: 0.29776665568351746
# 35 gen | avg. population acc: 0.2987966537475586
# 36 gen | avg. population acc: 0.3037533462047577
# 37 gen | avg. population acc: 0.30764833092689514
# 38 gen | avg. population acc: 0.30996668338775635
# 39 gen | avg. population acc: 0.3127816915512085
# 40 gen | avg. population acc: 0.3146316409111023
# 41 gen | avg. population acc: 0.31560999155044556
# 42 gen | avg. population acc: 0.317648321390152
# 43 gen | avg. population acc: 0.3205416798591614
# 44 gen | avg. population acc: 0.3236050009727478
# 45 gen | avg. population acc: 0.3281150162220001
# 46 gen | avg. population acc: 0.3322950005531311
# 47 gen | avg. population acc: 0.336029976606369
# 48 gen | avg. population acc: 0.34066665172576904
# 49 gen | avg. population acc: 0.3460350036621094
# avg test accuracy: 0.34881
#
#   - hit checkpoint! next run coming..
#   - run 2
# 0 gen | avg. population acc: 0.09739665687084198
# 1 gen | avg. population acc: 0.11245666444301605
